# %%
import pandas as pd

# %%
data2017=pd.read_csv("2017.csv")
data2017.head()
# Out:
#    tripduration       starttime        stoptime  start station id  \
# 0           410  10/1/2017 0:03  10/1/2017 0:09              3213
# 1           412  10/1/2017 0:03  10/1/2017 0:10              3213
# 2           274  10/1/2017 0:24  10/1/2017 0:28              3195
# 3          2198  10/1/2017 0:31  10/1/2017 1:07              3199
# 4           166  10/1/2017 0:34  10/1/2017 0:36              3186
#
#   start station name  start station latitude  start station longitude  \
# 0     Van Vorst Park               40.718489               -74.047727
# 1     Van Vorst Park               40.718489               -74.047727
# 2            Sip Ave               40.730743               -74.063784
# 3       Newport Pkwy               40.728745               -74.032108
# 4      Grove St PATH               40.719586               -74.043117
#
#    end station id    end station name  end station latitude  \
# 0            3192  Liberty Light Rail             40.711242
# ...

# %%
data2018=pd.read_csv("2018.csv")
data2018.head()
# Out:
#    tripduration       starttime        stoptime  start station id  \
# 0           260  11/1/2019 0:02  11/1/2019 0:07              3186
# 1           285  11/1/2019 0:05  11/1/2019 0:10              3206
# 2           501  11/1/2019 0:05  11/1/2019 0:14              3186
# 3           556  11/1/2019 0:07  11/1/2019 0:17              3209
# 4           321  11/1/2019 0:11  11/1/2019 0:17              3273
#
#   start station name  start station latitude  start station longitude  \
# 0      Grove St PATH               40.719586               -74.043117
# 1            Hilltop               40.731169               -74.057574
# 2      Grove St PATH               40.719586               -74.043117
# 3       Brunswick St               40.724176               -74.050656
# 4       Manila & 1st               40.721651               -74.042884
#
#    end station id    end station name  end station latitude  \
# 0            3203       Hamilton Park             40.727596
# ...

# %%
combine_data=data2017.append(data2018, ignore_index=False)

# %%
print(combine_data)
# Out:
#        tripduration         starttime          stoptime  start station id  \
# 0               410    10/1/2017 0:03    10/1/2017 0:09              3213
# 1               412    10/1/2017 0:03    10/1/2017 0:10              3213
# 2               274    10/1/2017 0:24    10/1/2017 0:28              3195
# 3              2198    10/1/2017 0:31    10/1/2017 1:07              3199
# 4               166    10/1/2017 0:34    10/1/2017 0:36              3186
# ...             ...               ...               ...               ...
# 30792            77  11/30/2019 23:30  11/30/2019 23:31              3638
# 30793           145  11/30/2019 23:40  11/30/2019 23:43              3211
# 30794            99  11/30/2019 23:41  11/30/2019 23:43              3792
# 30795           594  11/30/2019 23:52    12/1/2019 0:02              3213
# 30796           329  11/30/2019 23:56    12/1/2019 0:01              3185
#
#                start station name  start station latitude  \
# ...

# %%
combine_data.tail()
# Out:
#        tripduration         starttime          stoptime  start station id  \
# 30792            77  11/30/2019 23:30  11/30/2019 23:31              3638
# 30793           145  11/30/2019 23:40  11/30/2019 23:43              3211
# 30794            99  11/30/2019 23:41  11/30/2019 23:43              3792
# 30795           594  11/30/2019 23:52    12/1/2019 0:02              3213
# 30796           329  11/30/2019 23:56    12/1/2019 0:01              3185
#
#                start station name  start station latitude  \
# 30792               Washington St               40.724294
# 30793                  Newark Ave               40.721525
# 30794  Columbus Dr at Exchange Pl               40.716870
# 30795              Van Vorst Park               40.718489
# 30796                   City Hall               40.717733
#
#        start station longitude  end station id  end station name  \
# 30792               -74.035483            3202      Newport PATH
# ...

# %%
combine_data.to_csv("MergedBikeData2017to2018.csv", index=False)
